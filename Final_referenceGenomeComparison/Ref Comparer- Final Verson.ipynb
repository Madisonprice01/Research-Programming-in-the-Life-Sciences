# %%
import sys 

class RefComparer:
    ''' Take as input three lists containing information 
    regarding CRISPR guide counts in old reference genome, 
    new reference genome, and novel regions. Find the CRISPR 
    guide sequences that are used in both the old and new 
    references and flag the guides that have different counts 
    between the two references.'''

    def __init__(self, file1Lines, file2Lines, file3Lines):
        '''Initialize a RefComparer object with all attributes
        given at instantiation time.'''
        
        self.dict1 = {}  #hg38
        self.dict2 = {}  #chm13
        self.dict3 = {}  #chm13*
        self.set1 = set()
        self.set2 = set()
        self.set3 = set()
        self.guidesInBoth = set()
        self.flaggedGuides = []
        self.file1Lines = file1Lines
        self.file2Lines = file2Lines
        self.file3Lines = file3Lines
        
    def buildDictList(self):
        '''Read two lists containing CRISPR guide counts from 
        reference genomes and add each element's information to a 
        dictionary and set.'''
      
        for line in self.file1Lines:          # old reference
            x = line.strip()                  # strip new newline characters
            y = x.split('\t')                 # split around white space
            self.dict1[y[0]] = y[1]           # assign guide seq and count as key-value pair
            self.set1.add(y[0])               # add guide sequence to set
        
        for line in self.file2Lines:          # new reference 
            x = line.strip()                  # same procedure
            y = x.split('\t')                           
            self.dict2[y[0]] = y[1]
            self.set2.add(y[0])
         
        for line in self.file3Lines:          # novel regions 
            x = line.strip()                  # same procedure
            y = x.split('\t')                            
            self.dict3[y[0]] = y[1]
            self.set3.add(y[0])
            if y[0] not in self.dict1:        # check if guides in novel regions are in old ref dictionary
                self.dict1[y[0]] = 0          # add key-value pair ith value of zero if not
        
        for line in self.file1Lines:          # re-iterate over old reference
            x = line.strip()                            
            y = x.split('\t') 
            if y[0] not in self.dict3:        # check if guides in old ref are in novel regions dict
                self.dict3[y[0]] = 0          # add key-value pair ith value of zero if not
    
        return (self.dict1, self.dict2, self.dict3, self.set1, self.set2, self.set3)
        
    def setIntersection(self):
        '''Calculate and return the intersection of two sets.'''
        
        self.guidesInBoth = self.set1.intersection(self.set2)   # intersection of old and new ref dicts = guides in both
        
        return self.guidesInBoth
                
    def dictCompare(self):
        '''Compare two dictionaries and store keys that have 
        different values in a list.'''

        for guide in self.guidesInBoth:                         # compare guides cunt in old and new ref   
            if self.dict1[guide] != self.dict2[guide]:          # flag guides that have dif counts 
                self.flaggedGuides.append(guide)                
            else:
                pass
            
        return self.flaggedGuides

    
    
def main():
    '''Use the RefComparer class to find the CRISPR guides that have different counts between old and new reference genomes. 
    Output these guide sequences and their counts in each reference and the novel regions.'''
    
    file1Name = input("Enter the name of your old reference text file: ")     # take old ref file name from user input
    with open(file1Name) as file1:                                           # open file 
        myFile1 = file1.readlines()                                          # create a list which file lines as elements
    file2Name = input("Enter the name of your new reference text file: ")     # same procedure
    with open(file2Name) as file2:
        myFile2 = file2.readlines()
    file3Name = input("Enter the name of your novel regions text file: ")     # same procedure
    with open(file3Name) as file3:
        myFile3 = file3.readlines()
    
    
    classObject = RefComparer(myFile1, myFile2, myFile3)                     # instantiate class object
        
    (dict1, dict2, dict3, list1, list2, list3) = classObject.buildDictList() # build dictonaries for each ref
    
    guidesInBoth = classObject.setIntersection()                             # generate set of guides used in old and new refs
    
    flaggedGuides = classObject.dictCompare()                                # generate list of guides that have diff counts 
    
    
    output = set()    
    
    for flagged in flaggedGuides:                                            # compare counts of flagged guides
        if dict2[flagged] > dict1[flagged]:                                  # only output guides w/ new count > old count 
            output.add((flagged,dict1[flagged],dict2[flagged], abs(int(dict1[flagged])-int(dict2[flagged]))))
        else:
            pass
        
    
    sortedOutput = sorted(output, key = lambda x: (x[3], x[1]), reverse = True)  
    
    print()
    print('There are '+str(len(guidesInBoth))+' CRISPR guides used in both the old and new references.')
    print('Of those, there are '+str(len(guidesInBoth)-len(flaggedGuides))+' CRISPR guides with the same counts and '+str(len(flaggedGuides))+' with different counts.')
    print()
    print('Here are the '+str(len(flaggedGuides))+' guides with different counts, including how often they occur in the novel regions:') 
    print()
    print('{:^24}{:^24}{:^24}{:^24}'.format('Guide',file1Name,file2Name,file3Name))
    print('-'*100)
    
    for x in sortedOutput:
        print('{:^24}{:^24}{:^24}{:^24}'.format(x[0],dict1[x[0]],dict2[x[0]], dict3[x[0]]))
       
    
if __name__ == "__main__":
    main()
# Out:
# Enter the name of your old reference text file: hg38test.txt
# Enter the name of your new reference text file: chm13test.txt
# Enter the name of your novel regions text file: chm13star-1000.txt
#
# There are 985 CRISPR guides used in both the old and new references.
# Of those, there are 302 CRISPR guides with the same counts and 683 with different counts.
#
# Here are the 683 guides with different counts, including how often they occur in the novel regions:
#
#          Guide                hg38test.txt           chm13test.txt         chm13star-1000.txt
# ----------------------------------------------------------------------------------------------------
# AAAAAAAAAAAAAAAAATGC.TGG          163                     178                      0
# AAAAAAAAAAAAAAAAACTC.AGG           43                      57                      0
# AAAAAAAAAAAAAAAAAATG.TGG          100                     112                      0
# AAAAAAAAAAAAAAAACCTA.TGG           10                      21                      12
# AAAAAAAAAAAAAAAAAAGA.GGG          617                     626                      5
# AAAAAAAAAAAAAAAATAGC.TGG          523                     532                      14
# AAAAAAAAAAAAAAAATGCT.GGG          132                     141                      0
# AAAAAAAAAAAAAAAAATAC.AGG           62                      70                      1
# AAAAAAAAAAAAAAAAATCA.AGG          103                      95                      1
# AAAAAAAAAAAAAAAATAGC.CGG          287                     294                      4
# AAAAAAAAAAAAAAAAAGGC.GGG          143                     150                      1
# AAAAAAAAAAAAAAAAAGGA.TGG          112                     119                      0
# AAAAAAAAAAAAAAAAAGGG.TGG          104                      97                      0
# AAAAAAAAAAAAAAAAACAA.AGG           81                      87                      1
# AAAAAAAAAAAAAAAAATGA.TGG           30                      36                      0
# AAAAAAAAAAAAAAAAAACA.AGG          194                     200                      7
# AAAAAAAAAAAAAAAAACTA.GGG           18                      24                      0
# AAAAAAAAAAAAAAAAAATT.TGG          157                     163                      0
# AAAAAAAAAAAAAAAAAAAT.CGG          100                      94                      4
# AAAAAAAAAAAAAAAATGCC.AGG           76                      81                      0
# AAAAAAAAAAAAAAAAGACC.GGG           40                      45                      1
# AAAAAAAAAAAAAAAAACCT.TGG           30                      35                      0
# AAAAAAAAAAAAAAAATGCA.GGG           18                      23                      0
# AAAAAAAAAAAAAAAAACAT.AGG           11                      16                      1
# AAAAAAAAAAAAAAAAGAAC.TGG          100                     105                      1
# AAAAAAAAAAAAAAAAAACT.AGG           95                      99                      1
# AAAAAAAAAAAAAAAAAGCC.CGG           58                      62                      2
# AAAAAAAAAAAAAAAAATCT.AGG           57                      61                      0
# AAAAAAAAAAAAAAAATAGC.GGG           18                      20                      0
# AAAAAAAAAAAAAAAAACAT.TGG           17                      19                      1
# AAAAAAAAAAAAAAAATGCA.TGG           15                      17                      0
# AAAAAAAAAAAAAAAATGAG.TGG           14                      16                      0
# AAAAAAAAAAAAAAAACGCT.GGG           13                      15                      0
# AAAAAAAAAAAAAAAAAAGA.CGG          126                     128                      2
# AAAAAAAAAAAAAAACAACT.TGG           12                      14                      0
# AAAAAAAAAAAAAAAATGGC.AGG           12                      14                      0
# AAAAAAAAAAAAAAAAACCA.CGG           11                      9                       0
# AAAAAAAAAAAAAAAATCTG.GGG           11                      9                       0
# AAAAAAAAAAAAAAAAAACT.GGG          104                     106                      0
# AAAAAAAAAAAAAAAAAACT.CGG           10                      12                      0
# AAAAAAAAAAAAAAACAATT.AGG           10                      12                      0
# AAAAAAAAAAAAAAAATGTC.AGG           10                      8                       0
# AAAAAAAAAAAAAAAACATA.TGG           1                       3                       0
# AAAAAAAAAAAAAAAAACCC.AGG           80                      81                      0
# AAAAAAAAAAAAAAAACCTG.GGG           8                       9                       0
# AAAAAAAAAAAAAAAATAAG.AGG           8                       9                       0
# AAAAAAAAAAAAAAAATAGT.CGG           8                       9                       0
# AAAAAAAAAAAAAAAAACGC.CGG           8                       9                       0
# AAAAAAAAAAAAAAAACAAA.TGG           8                       9                       0
# AAAAAAAAAAAAAAAAATGC.AGG           70                      71                      0
# AAAAAAAAAAAAAAAACTCA.TGG           7                       8                       0
# AAAAAAAAAAAAAAAACAAT.GGG           7                       8                       0
# AAAAAAAAAAAAAAAAGCCA.CGG           7                       8                       0
# AAAAAAAAAAAAAAAATTGG.CGG           7                       8                       1
# AAAAAAAAAAAAAAAAGGGT.CGG           7                       8                       0
# AAAAAAAAAAAAAAAATACT.AGG           7                       8                       0
# AAAAAAAAAAAAAAAAGAGT.GGG           66                      67                      2
# AAAAAAAAAAAAAAAAATTT.AGG           60                      61                      0
# AAAAAAAAAAAAAAAAATAT.GGG           6                       7                       1
# AAAAAAAAAAAAAAACAAAG.TGG           6                       7                       0
# AAAAAAAAAAAAAAAAGTTC.GGG           6                       7                       1
# AAAAAAAAAAAAAAACAAAA.CGG           6                       7                       0
# AAAAAAAAAAAAAAAAGTCC.GGG           54                      55                      0
# AAAAAAAAAAAAAAAAAGTC.CGG           51                      52                      0
# AAAAAAAAAAAAAAAATAGC.AGG           50                      51                      0
# AAAAAAAAAAAAAAAACAGT.CGG           5                       6                       0
# AAAAAAAAAAAAAAAATTCG.GGG           5                       6                       0
# AAAAAAAAAAAAAAAAACCT.CGG           5                       6                       0
# AAAAAAAAAAAAAAAAACCG.GGG           5                       6                       0
# AAAAAAAAAAAAAAAAGTCG.AGG           5                       6                       0
# AAAAAAAAAAAAAAAAACAG.TGG           47                      48                      0
# AAAAAAAAAAAAAAAAGTCC.TGG           46                      47                      0
# AAAAAAAAAAAAAAAAAGGT.CGG           44                      45                      1
# AAAAAAAAAAAAAAAAATGT.CGG           4                       5                       0
# AAAAAAAAAAAAAAAAGTGA.CGG           4                       5                       0
# AAAAAAAAAAAAAAACAAGT.GGG           4                       5                       0
# AAAAAAAAAAAAAAAAATAT.AGG           4                       5                       0
# AAAAAAAAAAAAAAAAGGAT.CGG           4                       5                       0
# AAAAAAAAAAAAAAAATTCC.CGG           4                       5                       0
# AAAAAAAAAAAAAAAAGTTA.CGG           4                       5                       0
# AAAAAAAAAAAAAAAACTAG.GGG           4                       5                       0
# AAAAAAAAAAAAAAAATCCC.AGG           39                      40                      1
# AAAAAAAAAAAAAAAAGGTA.GGG           39                      40                      0
# AAAAAAAAAAAAAAAATTTA.AGG           36                      37                      0
# AAAAAAAAAAAAAAAAGTGT.GGG           35                      36                      0
# AAAAAAAAAAAAAAAAACCA.TGG           35                      36                      0
# AAAAAAAAAAAAAAAAACAC.TGG           35                      36                      0
# AAAAAAAAAAAAAAAAATTT.GGG           34                      35                      0
# AAAAAAAAAAAAAAAAAATC.CGG           33                      34                      0
# AAAAAAAAAAAAAAAAGGTC.TGG           32                      33                      0
# AAAAAAAAAAAAAAAATCTC.AGG           31                      32                      0
# AAAAAAAAAAAAAAAAGCCC.GGG           30                      31                      0
# AAAAAAAAAAAAAAAATTAT.AGG           30                      31                      0
# AAAAAAAAAAAAAAAACGGG.AGG           3                       4                       0
# AAAAAAAAAAAAAAAACAAC.CGG           3                       4                       0
# AAAAAAAAAAAAAAAAGCCC.CGG           3                       4                       0
# AAAAAAAAAAAAAAAAACCA.GGG           28                      29                      0
# AAAAAAAAAAAAAAAAGCAT.GGG           27                      28                      0
# AAAAAAAAAAAAAAAATCTC.TGG           27                      28                      1
# AAAAAAAAAAAAAAAAGAAA.CGG           26                      27                      1
# AAAAAAAAAAAAAAAAAGCG.TGG           26                      27                      0
# AAAAAAAAAAAAAAAATTAG.AGG           26                      27                      0
# AAAAAAAAAAAAAAAAACTG.GGG           25                      26                      0
# AAAAAAAAAAAAAAAAGAGA.CGG           23                      24                      0
# AAAAAAAAAAAAAAAAGTAC.TGG           23                      24                      0
# AAAAAAAAAAAAAAAATTTC.AGG           23                      24                      0
# AAAAAAAAAAAAAAAAATCC.GGG           23                      24                      0
# AAAAAAAAAAAAAAAAACTG.TGG           23                      24                      1
# AAAAAAAAAAAAAAAAAGTC.AGG          226                     227                      2
# AAAAAAAAAAAAAAAATTTG.TGG           22                      23                      0
# AAAAAAAAAAAAAAAATCTT.TGG           21                      22                      0
# AAAAAAAAAAAAAAAAGTAT.GGG           21                      22                      0
# AAAAAAAAAAAAAAAATGGT.GGG           21                      22                      0
# AAAAAAAAAAAAAAAAGGGA.TGG           21                      22                      0
# AAAAAAAAAAAAAAAAGTTA.GGG           21                      22                      0
# AAAAAAAAAAAAAAAATCAT.GGG           21                      22                      0
# AAAAAAAAAAAAAAAATCCT.TGG           21                      22                      0
# AAAAAAAAAAAAAAAATAGA.GGG           21                      22                      0
# AAAAAAAAAAAAAAAATCCC.TGG           20                      21                      0
# AAAAAAAAAAAAAAACAATC.TGG           2                       3                       0
# AAAAAAAAAAAAAAAAGTCA.CGG           2                       3                       0
# AAAAAAAAAAAAAAAATGTC.GGG           2                       3                       0
# AAAAAAAAAAAAAAAATCGA.AGG           2                       3                       0
# AAAAAAAAAAAAAAAAGTGT.CGG           2                       3                       0
# AAAAAAAAAAAAAAAACACG.AGG           2                       3                       1
# AAAAAAAAAAAAAAAAGCTT.TGG           19                      20                      0
# AAAAAAAAAAAAAAAACAGA.GGG           19                      20                      0
# AAAAAAAAAAAAAAAACCAC.TGG           19                      20                      2
# AAAAAAAAAAAAAAAATCTA.TGG           19                      20                      1
# AAAAAAAAAAAAAAAAAAGG.CGG          188                     189                      1
# AAAAAAAAAAAAAAAATCCA.TGG           17                      18                      0
# AAAAAAAAAAAAAAAACTTG.AGG           17                      18                      0
# AAAAAAAAAAAAAAAACTTT.TGG           16                      17                      0
# AAAAAAAAAAAAAAAACAGA.TGG           16                      17                      0
# AAAAAAAAAAAAAAAACAGG.AGG           16                      17                      0
# AAAAAAAAAAAAAAAAGAAT.AGG          159                     160                      0
# AAAAAAAAAAAAAAAATAGG.AGG           15                      16                      0
# AAAAAAAAAAAAAAAAAACG.TGG           15                      16                      0
# AAAAAAAAAAAAAAAACTCC.TGG           15                      16                      2
# AAAAAAAAAAAAAAAAATAG.CGG           15                      16                      0
# AAAAAAAAAAAAAAAAGGAC.GGG           15                      16                      0
# AAAAAAAAAAAAAAAACAAC.AGG           14                      15                      0
# AAAAAAAAAAAAAAAAAGTG.CGG           13                      14                      0
# AAAAAAAAAAAAAAAAACGG.GGG           13                      14                      0
# AAAAAAAAAAAAAAAAAGAT.CGG           13                      14                      0
# AAAAAAAAAAAAAAAATGGG.GGG           13                      14                      0
# AAAAAAAAAAAAAAAACTCA.AGG           13                      14                      0
# AAAAAAAAAAAAAAAACACC.TGG           12                      13                      0
# AAAAAAAAAAAAAAAATTTT.AGG           11                      12                      1
# AAAAAAAAAAAAAAAACTGC.TGG           11                      12                      0
# AAAAAAAAAAAAAAAACTAC.TGG           11                      12                      0
# AAAAAAAAAAAAAAACAAGC.TGG           11                      12                      0
# AAAAAAAAAAAAAAAAGAAC.AGG          109                     110                      1
# AAAAAAAAAAAAAAAATAGG.GGG           10                      11                      0
# AAAAAAAAAAAAAAAAAGTA.CGG           10                      11                      0
# AAAAAAAAAAAAAAAACAAT.AGG           10                      9                       0
# AAAAAAAAAAAAAAAACTAT.GGG           10                      9                       1
# AAAAAAAAAAAAAAAAGGAA.CGG           10                      9                       0
# AAAAAAAAAAAAAAAACTCT.TGG           10                      11                      0
# AAAAAAAAAAAAAAAACCCC.AGG           10                      9                       0
# AAAAAAAAAAAAAAAAGTTT.CGG           10                      9                       1
# AAAAAAAAAAAAAAAACCAA.TGG           10                      11                      0
# AAAAAAAAAAAAAAAAACGG.TGG           10                      11                      0
# AAAAAAAAAAAAAAACAAAC.AGG           10                      9                       0
# AAAAAAAAAAAAAAAACCGG.TGG           1                       2                       0
# AAAAAAAAAAAAAAAACGAG.GGG           1                       2                       0
# AAAAAAAAAAAAAAAACCCG.AGG           1                       2                       0
# AAAAAAAAAAAAAAAAACTC.GGG           1                       2                       0
# AAAAAAAAAAAAAAAATACC.GGG           1                       2                       0
# AAAAAAAAAAAAAAAACGTT.GGG           1                       2                       0
# AAAAAAAAAAAAAAAACGCA.GGG           1                       2                       0
# AAAAAAAAAAAAAAAATGTA.CGG           1                       2                       0
# AAAAAAAAAAAAAAACAATA.TGG           1                       2                       0
# AAAAAAAAAAAAAAAACGTA.GGG           1                       2                       0
